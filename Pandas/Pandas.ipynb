# %%
import pandas as pd

# %%
# list/numpy array/dictionary/set/tuple series can be created from any of these

data = [10,20,30,40,50,60,70]
data
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
s1 = pd.Series(data) # creating a series from sequence
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series(['hello1','hello2','hello3'])
s2
# Out:
# 0    hello1
# 1    hello2
# 2    hello3
# dtype: object

# %%
# create a dataframe
df = pd.DataFrame(['hello1','hello2','hello3'])
# Out:
#         0
# 0  hello1
# 1  hello2
# 2  hello3

# %%
# create a dataframe of two columns from a series
df = {"one":pd.Series([1.0,2.0,3.0], index=["A","B","C"]), "two":pd.Series([1.0,2.0,3.0],index=["A","B","C"])}
df = pd.DataFrame(df)
df
# Out:
#    one  two
# A  1.0  1.0
# B  2.0  2.0
# C  3.0  3.0

# %%
# source files to import and use for creating a dataframe

# 1.  .txt   - text document
# 2.  .html  - hypertext markup language
# 3.  .py    - python file
# 4.  .ipynb - interactive python notebook
# 5.  .xlsx  - excel spreadsheet
# 6.  .csv   - comma seperated values
# 7.  .tsv   - tab seperated values
# 8.  .sql   - structured query language
# 9   .xml   - extensible markup language
# 10. .json  - javascript object notation

# %%
df = pd.read_table("/content/demo.txt")
df
# Out:
#   Sl.No  UPPERCASE lowercase
# 1    AA        NaN        aa
# 2    BB        NaN        bb
# 3    CC        NaN        cc
# 4    DD        NaN        dd
# 5    EE        NaN        ee

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# methods to create a file
# pd.read_csv()
# pd.read_excel()

# %% [markdown]
# KAGGLE \
# two methods
# 1. raw file (download is stored on the cloud) (azure, aws-storage, googleapis, github)
# 2. download the file and upload it in the files section of the collab

# %%
# from raw file
df = pd.read_table("https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220619%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220619T122722Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df.columns
# Out:
# Index(['fruit_label', 'fruit_name', 'fruit_subtype', 'mass', 'width', 'height',
#        'color_score'],
#       dtype='object')

# %%
df.shape #rows,columns
# Out:
# (59, 7)

# %%
df.size #total no. of values (rows*columns)
# Out:
# 413

# %%
df.info() # gives complete information regarding the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
df.isnull().sum()
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
df.head(7)
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79
# 5            2   mandarin      mandarin    80    5.8     4.3         0.77
# 6            2   mandarin      mandarin    80    5.9     4.3         0.81

# %%
df.tail()
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 54            4      lemon       unknown   116    6.1     8.5         0.71
# 55            4      lemon       unknown   116    6.3     7.7         0.72
# 56            4      lemon       unknown   116    5.9     8.1         0.73
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70

# %%
df.describe() # summary statistics of the dataframe
# Out:
#        fruit_label        mass      width     height  color_score
# count    59.000000   59.000000  59.000000  59.000000    59.000000
# mean      2.542373  163.118644   7.105085   7.693220     0.762881
# std       1.208048   55.018832   0.816938   1.361017     0.076857
# min       1.000000   76.000000   5.800000   4.000000     0.550000
# 25%       1.000000  140.000000   6.600000   7.200000     0.720000
# 50%       3.000000  158.000000   7.200000   7.600000     0.750000
# 75%       4.000000  177.000000   7.500000   8.200000     0.810000
# max       4.000000  362.000000   9.600000  10.500000     0.930000

# %%
df[10:20] #inclusive:exclusive # print 10-20 rows
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# 11            1      apple          braeburn   172    7.1     7.6         0.92
# 12            1      apple          braeburn   154    7.0     7.1         0.88
# 13            1      apple  golden_delicious   164    7.3     7.7         0.70
# 14            1      apple  golden_delicious   152    7.6     7.3         0.69
# 15            1      apple  golden_delicious   156    7.7     7.1         0.69
# 16            1      apple  golden_delicious   156    7.6     7.5         0.67
# 17            1      apple  golden_delicious   168    7.5     7.6         0.73
# 18            1      apple       cripps_pink   162    7.5     7.1         0.83
# 19            1      apple       cripps_pink   162    7.4     7.2         0.85

# %%
df.iloc[25:30,0:3] # iloc: integer location based indexing for selecting rows
# Out:
#     fruit_label fruit_name     fruit_subtype
# 25            3     orange     spanish_jumbo
# 26            3     orange     spanish_jumbo
# 27            3     orange  selected_seconds
# 28            3     orange  selected_seconds
# 29            3     orange  selected_seconds

# %%
df.iloc[25:30,[5,2,6,1]] # for selecting specific columns
# Out:
#     height     fruit_subtype  color_score fruit_name
# 25     9.2     spanish_jumbo         0.75     orange
# 26     9.2     spanish_jumbo         0.74     orange
# 27     9.2  selected_seconds         0.77     orange
# 28     7.1  selected_seconds         0.72     orange
# 29     7.4  selected_seconds         0.81     orange

# %%
fname = df.fruit_name # create a series for a column
fname
# Out:
# 0        apple
# 1        apple
# 2        apple
# 3     mandarin
# 4     mandarin
# 5     mandarin
# 6     mandarin
# 7     mandarin
# 8        apple
# 9        apple
# 10       apple
# 11       apple
# 12       apple
# 13       apple
# 14       apple
# 15       apple
# 16       apple
# 17       apple
# 18       apple
# 19       apple
# 20       apple
# 21       apple
# 22       apple
# 23       apple
# 24      orange
# 25      orange
# 26      orange
# 27      orange
# 28      orange
# 29      orange
# 30      orange
# 31      orange
# 32      orange
# 33      orange
# 34      orange
# 35      orange
# 36      orange
# 37      orange
# 38      orange
# 39      orange
# 40      orange
# 41      orange
# 42      orange
# 43       lemon
# 44       lemon
# 45       lemon
# 46       lemon
# 47       lemon
# 48       lemon
# 49       lemon
# 50       lemon
# 51       lemon
# 52       lemon
# 53       lemon
# 54       lemon
# 55       lemon
# 56       lemon
# 57       lemon
# ...

# %%
fname = df.fruit_name.unique() # name of the unique elements
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
df.fruit_name.nunique() # count of unique in df
# Out:
# 4

# %%
fsize = df.groupby('fruit_name',sort=False).size()
fsize
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
df['fruit_name'] # create a series from column
# Out:
# 0        apple
# 1        apple
# 2        apple
# 3     mandarin
# 4     mandarin
# 5     mandarin
# 6     mandarin
# 7     mandarin
# 8        apple
# 9        apple
# 10       apple
# 11       apple
# 12       apple
# 13       apple
# 14       apple
# 15       apple
# 16       apple
# 17       apple
# 18       apple
# 19       apple
# 20       apple
# 21       apple
# 22       apple
# 23       apple
# 24      orange
# 25      orange
# 26      orange
# 27      orange
# 28      orange
# 29      orange
# 30      orange
# 31      orange
# 32      orange
# 33      orange
# 34      orange
# 35      orange
# 36      orange
# 37      orange
# 38      orange
# 39      orange
# 40      orange
# 41      orange
# 42      orange
# 43       lemon
# 44       lemon
# 45       lemon
# 46       lemon
# 47       lemon
# 48       lemon
# 49       lemon
# 50       lemon
# 51       lemon
# 52       lemon
# 53       lemon
# 54       lemon
# 55       lemon
# 56       lemon
# 57       lemon
# ...

# %%
df['fruit_name'].value_counts() # number of times each element is repeated
# Out:
# apple       19
# orange      19
# lemon       16
# mandarin     5
# Name: fruit_name, dtype: int64

# %%
df['fruit_name'].value_counts().plot(kind='bar')

# %%
import matplotlib.pyplot as plt
width1 = df['width'] # series 1
height1 = df['height'] # series 2
plt.scatter(width1,height1)
